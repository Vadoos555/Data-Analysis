# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# 3                               Employed full-time                Thailand
# 4                               Employed full-time           United States
# 5                               Employed full-time                 Ukraine
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
# 3                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
#
#                                                      EduOther  \
# Respondent
# 1           Taught yourself a new language, framework, or ...
# 2           Taken an online course in programming or softw...
# 3           Taught yourself a new language, framework, or ...
# 4           Taken an online course in programming or softw...
# 5           Taken an online course in programming or softw...
#
#                              OrgSize  \
# Respondent
# 1                                NaN
# 2                                NaN
# 3               100 to 499 employees
# 4               100 to 499 employees
# 5           10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 1                                                         NaN         4
# 2           Developer, desktop or enterprise applications;...       NaN
# 3           Designer;Developer, back-end;Developer, front-...         3
# 4                                       Developer, full-stack         3
# 5           Academic researcher;Developer, desktop or ente...        16
#
#            Age1stCode      YearsCodePro           CareerSat  \
# Respondent
# 1                  10               NaN                 NaN
# 2                  17               NaN                 NaN
# 3                  22                 1  Slightly satisfied
# 4                  16  Less than 1 year      Very satisfied
# 5                  14                 9   Very dissatisfied
#
#                            JobSat              MgrIdiot  MgrMoney   MgrWant  \
# Respondent
# 1                             NaN                   NaN       NaN       NaN
# 2                             NaN                   NaN       NaN       NaN
# 3              Slightly satisfied  Not at all confident  Not sure  Not sure
# 4              Slightly satisfied        Very confident        No  Not sure
# 5           Slightly dissatisfied    Somewhat confident       Yes        No
#
#                                                       JobSeek  \
# Respondent
# 1                                                         NaN
# 2                             I am actively looking for a job
# 3           I’m not actively looking, but I am open to new...
# 4                I am not interested in new job opportunities
# 5                I am not interested in new job opportunities
#
#                     LastHireDate  \
# Respondent
# 1                            NaN
# 2           I've never had a job
# 3                  1-2 years ago
# 4           Less than a year ago
# 5           Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 1                                                         NaN      NaN
# 2                                                         NaN      NaN
# 3                         Interview with people in peer roles       No
# 4           Write code by hand (e.g., on a whiteboard);Int...       No
# 5           Write any code;Write code by hand (e.g., on a ...       No
#
#                                                    JobFactors  \
# Respondent
# 1                                                         NaN
# 2           Financial performance or funding status of the...
# 3           Languages, frameworks, and other technologies ...
# 4           Languages, frameworks, and other technologies ...
# 5           Industry that I'd be working in;Languages, fra...
#
#                                                  ResumeUpdate CurrencySymbol  \
# Respondent
# 1                                                         NaN            NaN
# 2           Something else changed (education, award, medi...            NaN
# 3                            I was preparing for a job search            THB
# 4                            I was preparing for a job search            USD
# 5                            I was preparing for a job search            UAH
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 1                            NaN        NaN      NaN            NaN
# 2                            NaN        NaN      NaN            NaN
# 3                      Thai baht    23000.0  Monthly         8820.0
# 4           United States dollar    61000.0   Yearly        61000.0
# 5              Ukrainian hryvnia        NaN      NaN            NaN
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 1                   NaN                                                NaN
# 2                   NaN                                                NaN
# 3                  40.0  There's no schedule or spec; I work on what se...
# 4                  80.0  There's no schedule or spec; I work on what se...
# 5                  55.0  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3           Distracting work environment;Inadequate access...
# 4                                                         NaN
# 5           Being tasked with non-development work;Inadequ...
#
#                                   WorkRemote WorkLoc                  ImpSyn  \
# Respondent
# 1                                        NaN     NaN                     NaN
# 2                                        NaN     NaN                     NaN
# 3           Less than once per month / Never    Home                 Average
# 4           Less than once per month / Never    Home  A little below average
# 5                      A few days each month  Office  A little above average
#
#                                             CodeRev  CodeRevHrs  \
# Respondent
# 1                                               NaN         NaN
# 2                                               NaN         NaN
# 3                                                No         NaN
# 4                                                No         NaN
# 5           Yes, because I see value in code review         NaN
#
#                                 UnitTests  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3               No, but I think we should
# 4               No, but I think we should
# 5           Yes, it's part of our process
#
#                                                   PurchaseHow  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                                                    Not sure
# 4           Developers typically have the most influence o...
# 5                                                    Not sure
#
#                              PurchaseWhat  \
# Respondent
# 1                                     NaN
# 2                                     NaN
# 3           I have little or no influence
# 4           I have little or no influence
# 5           I have little or no influence
#
#                                      LanguageWorkedWith  \
# Respondent
# 1                       HTML/CSS;Java;JavaScript;Python
# 2                                   C++;HTML/CSS;Python
# 3                                              HTML/CSS
# 4                                   C;C++;C#;Python;SQL
# 5           C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
#
#                                      LanguageDesireNextYear  \
# Respondent
# 1           C;C++;C#;Go;HTML/CSS;Java;JavaScript;Python;SQL
# 2                               C++;HTML/CSS;JavaScript;SQL
# 3                                           Elixir;HTML/CSS
# 4                                       C;C#;JavaScript;SQL
# 5                  HTML/CSS;Java;JavaScript;SQL;WebAssembly
#
#                                           DatabaseWorkedWith  \
# Respondent
# 1                                                     SQLite
# 2                                                        NaN
# 3                                                 PostgreSQL
# 4                                               MySQL;SQLite
# 5           Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 1                                                       MySQL
# 2                                                       MySQL
# 3                                                  PostgreSQL
# 4                                                MySQL;SQLite
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
#
#                            PlatformWorkedWith  \
# Respondent
# 1                               MacOS;Windows
# 2                                     Windows
# 3                                         NaN
# 4                               Linux;Windows
# 5           Android;Linux;MacOS;Slack;Windows
#
#                            PlatformDesireNextYear  \
# Respondent
# 1                         Android;Arduino;Windows
# 2                                         Windows
# 3                                             NaN
# 4                                   Linux;Windows
# 5           Android;Docker;Kubernetes;Linux;Slack
#
#                                      WebFrameWorkedWith  \
# Respondent
# 1                                          Django;Flask
# 2                                                Django
# 3                                                   NaN
# 4                                                   NaN
# 5           Django;Express;Flask;jQuery;React.js;Spring
#
#                   WebFrameDesireNextYear MiscTechWorkedWith  \
# Respondent
# 1                           Flask;jQuery            Node.js
# 2                                 Django                NaN
# 3                              Other(s):                NaN
# 4                                    NaN               .NET
# 5           Flask;jQuery;React.js;Spring    Cordova;Node.js
#
#                               MiscTechDesireNextYear  \
# Respondent
# 1                                            Node.js
# 2                                                NaN
# 3                                                NaN
# 4                                               .NET
# 5           Apache Spark;Hadoop;Node.js;React Native
#
#                                               DevEnviron        OpSys  \
# Respondent
# 1                             IntelliJ;Notepad++;PyCharm      Windows
# 2                                           Atom;PyCharm      Windows
# 3                                 Vim;Visual Studio Code  Linux-based
# 4           Eclipse;Vim;Visual Studio;Visual Studio Code      Windows
# 5                                 IntelliJ;Notepad++;Vim  Linux-based
#
#                                         Containers BlockchainOrg  \
# Respondent
# 1                          I do not use containers           NaN
# 2                          I do not use containers           NaN
# 3                          I do not use containers           NaN
# 4                          I do not use containers    Not at all
# 5           Outside of work, for personal projects    Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 1                                                         NaN        Yes
# 2           Useful across many domains and could change ma...        Yes
# 3                                                         NaN        Yes
# 4           Useful for decentralized currency (i.e., Bitcoin)        Yes
# 5                                                         NaN        Yes
#
#                                             ITperson OffOn SocialMedia  \
# Respondent
# 1           Fortunately, someone else has that title   Yes     Twitter
# 2                                                Yes   Yes   Instagram
# 3                                                Yes   Yes      Reddit
# 4                                               SIGH   Yes      Reddit
# 5                                           Also Yes   Yes    Facebook
#
#                         Extraversion ScreenName        SOVisit1st  \
# Respondent
# 1                             Online   Username              2017
# 2                             Online   Username              2017
# 3           In real life (in person)   Username              2011
# 4           In real life (in person)   Username              2014
# 5           In real life (in person)   Username  I don't remember
#
#                                 SOVisitFreq  \
# Respondent
# 1           A few times per month or weekly
# 2                     Daily or almost daily
# 3                      A few times per week
# 4                     Daily or almost daily
# 5                    Multiple times per day
#
#                                                     SOVisitTo  \
# Respondent
# 1           Find answers to specific questions;Learn how t...
# 2           Find answers to specific questions;Learn how t...
# 3           Find answers to specific questions;Learn how t...
# 4           Find answers to specific questions;Pass the ti...
# 5                          Find answers to specific questions
#
#                            SOFindAnswer                     SOTimeSaved  \
# Respondent
# 1                    3-5 times per week  Stack Overflow was much faster
# 2                    3-5 times per week  Stack Overflow was much faster
# 3                   6-10 times per week        They were about the same
# 4                    1-2 times per week  Stack Overflow was much faster
# 5           More than 10 times per week  Stack Overflow was much faster
#
#             SOHowMuchTime SOAccount                           SOPartFreq  \
# Respondent
# 1           31-60 minutes        No                                  NaN
# 2           11-30 minutes       Yes      A few times per month or weekly
# 3                     NaN       Yes  Less than once per month or monthly
# 4           31-60 minutes       Yes  Less than once per month or monthly
# 5                     NaN       Yes      A few times per month or weekly
#
#                                                        SOJobs  \
# Respondent
# 1           No, I didn't know that Stack Overflow had a jo...
# 2           No, I knew that Stack Overflow had a job board...
# 3                                                         Yes
# 4                                                         Yes
# 5           No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 1                         No, and I don't know what those are
# 2                         No, and I don't know what those are
# 3           No, I've heard of them, but I am not part of a...
# 4                         No, and I don't know what those are
# 5           No, I've heard of them, but I am not part of a...
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 1                   Neutral  Just as welcome now as I felt last year
# 2             Yes, somewhat  Just as welcome now as I felt last year
# 3                   Neutral  Just as welcome now as I felt last year
# 4            No, not really  Just as welcome now as I felt last year
# 5           Yes, definitely  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
#
#                                            Ethnicity Dependents  \
# Respondent
# 1                                                NaN         No
# 2                                                NaN         No
# 3                                                NaN        Yes
# 4                       White or of European descent         No
# 5           White or of European descent;Multiracial         No
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy

# %%
filt = (df['Country'] == 'Ukraine')
ukr_df = df.loc[filt]
ukr_df.head()
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 5           I am a developer by profession      Yes
# 7           I am a developer by profession       No
# 329         I am a developer by profession      Yes
# 371         I am a developer by profession       No
# 521         I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 5           Once a month or more often
# 7                                Never
# 329            Less than once per year
# 371                              Never
# 521                              Never
#
#                                                    OpenSource  \
# Respondent
# 5           OSS is, on average, of HIGHER quality than pro...
# 7           The quality of OSS and closed source software ...
# 329         The quality of OSS and closed source software ...
# 371         OSS is, on average, of LOWER quality than prop...
# 521         The quality of OSS and closed source software ...
#
#                                                    Employment  Country  \
# Respondent
# 5                                          Employed full-time  Ukraine
# 7           Independent contractor, freelancer, or self-em...  Ukraine
# 329                                        Employed full-time  Ukraine
# 371                                        Employed full-time  Ukraine
# 521                                        Employed full-time  Ukraine
#
#            Student                                            EdLevel  \
# Respondent
# 5               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 329            NaN  Some college/university study without earning ...
# 371             No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 521             No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 5           Computer science, computer engineering, or sof...
# 7           Another engineering discipline (ex. civil, ele...
# 329         Computer science, computer engineering, or sof...
# 371         Computer science, computer engineering, or sof...
# 521         Another engineering discipline (ex. civil, ele...
#
#                                                      EduOther  \
# Respondent
# 5           Taken an online course in programming or softw...
# 7           Taught yourself a new language, framework, or ...
# 329                                                       NaN
# 371                                                       NaN
# 521         Taken an online course in programming or softw...
#
#                                                       OrgSize  \
# Respondent
# 5                                    10,000 or more employees
# 7           Just me - I am a freelancer, sole proprietor, ...
# 329                                      100 to 499 employees
# 371                                      500 to 999 employees
# 521                                  10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 5           Academic researcher;Developer, desktop or ente...        16
# 7                               Designer;Developer, front-end         6
# 329         Academic researcher;Database administrator;Des...        20
# 371         Data or business analyst;Database administrato...        10
# 521                                      Developer, front-end         5
#
#            Age1stCode YearsCodePro                           CareerSat  \
# Respondent
# 5                  14            9                   Very dissatisfied
# 7                  17            4                  Slightly satisfied
# 329                15           10  Neither satisfied nor dissatisfied
# 371                21            7                      Very satisfied
# 521                 8            5                      Very satisfied
#
#                                         JobSat              MgrIdiot MgrMoney  \
# Respondent
# 5                        Slightly dissatisfied    Somewhat confident      Yes
# 7           Neither satisfied nor dissatisfied                   NaN      NaN
# 329         Neither satisfied nor dissatisfied  Not at all confident       No
# 371                             Very satisfied    Somewhat confident       No
# 521                         Slightly satisfied    Somewhat confident      Yes
#
#            MgrWant                                            JobSeek  \
# Respondent
# 5               No       I am not interested in new job opportunities
# 7              NaN  I’m not actively looking, but I am open to new...
# 329             No  I’m not actively looking, but I am open to new...
# 371             No       I am not interested in new job opportunities
# 521             No       I am not interested in new job opportunities
#
#                                                  LastHireDate  \
# Respondent
# 5                                        Less than a year ago
# 7           NA - I am an independent contractor or self em...
# 329                                     More than 4 years ago
# 371                                      Less than a year ago
# 521                                      Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 5           Write any code;Write code by hand (e.g., on a ...       No
# 7                                              Write any code       No
# 329         Write any code;Write code by hand (e.g., on a ...       No
# 371         Interview with people in senior / management r...       No
# 521         Complete a take-home project;Interview with pe...       No
#
#                                                    JobFactors  \
# Respondent
# 5           Industry that I'd be working in;Languages, fra...
# 7           Remote work options;Opportunities for professi...
# 329         Financial performance or funding status of the...
# 371         Financial performance or funding status of the...
# 521         Financial performance or funding status of the...
#
#                                 ResumeUpdate CurrencySymbol  \
# Respondent
# 5           I was preparing for a job search            UAH
# 7                                        NaN            USD
# 329         I was preparing for a job search            USD
# 371         I was preparing for a job search            UAH
# 521         I was preparing for a job search            USD
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 5              Ukrainian hryvnia        NaN      NaN            NaN
# 7           United States dollar        NaN      NaN            NaN
# 329         United States dollar     4000.0  Monthly        48000.0
# 371            Ukrainian hryvnia        NaN      NaN            NaN
# 521         United States dollar     2300.0   Yearly         2300.0
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 5                  55.0  There is a schedule and/or spec (made by me or...
# 7                  32.0  There is a schedule and/or spec (made by me or...
# 329                 NaN  There is a schedule and/or spec (made by me or...
# 371                40.0  There is a schedule and/or spec (made by me or...
# 521                40.0  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 5           Being tasked with non-development work;Inadequ...
# 7           Being tasked with non-development work;Distrac...
# 329         Being tasked with non-development work;Distrac...
# 371                                                       NaN
# 521         Distracting work environment;Lack of support f...
#
#                                                    WorkRemote  \
# Respondent
# 5                                       A few days each month
# 7           All or almost all the time (I'm full-time remote)
# 329                                     A few days each month
# 371                                          It's complicated
# 521                          Less than once per month / Never
#
#                                                    WorkLoc  \
# Respondent
# 5                                                   Office
# 7           Other place, such as a coworking space or cafe
# 329                                                 Office
# 371                                                 Office
# 521                                                 Office
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 5           A little above average  Yes, because I see value in code review
# 7                          Average  Yes, because I see value in code review
# 329              Far above average  Yes, because I see value in code review
# 371         A little above average  Yes, because I see value in code review
# 521         A little above average  Yes, because I see value in code review
#
#             CodeRevHrs                      UnitTests PurchaseHow  \
# Respondent
# 5                  NaN  Yes, it's part of our process    Not sure
# 7                  6.0                            NaN         NaN
# 329                NaN  Yes, it's part of our process    Not sure
# 371                NaN  Yes, it's part of our process    Not sure
# 521                1.0      No, and I'm glad we don't    Not sure
#
#                              PurchaseWhat  \
# Respondent
# 5           I have little or no influence
# 7                                     NaN
# 329                 I have some influence
# 371                 I have some influence
# 521         I have little or no influence
#
#                                            LanguageWorkedWith  \
# Respondent
# 5                 C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7                                         HTML/CSS;JavaScript
# 329         C;C++;C#;F#;HTML/CSS;JavaScript;Rust;SQL;TypeS...
# 371                                 Bash/Shell/PowerShell;SQL
# 521                                       HTML/CSS;JavaScript
#
#                                  LanguageDesireNextYear  \
# Respondent
# 5              HTML/CSS;Java;JavaScript;SQL;WebAssembly
# 7                                   HTML/CSS;JavaScript
# 329         F#;JavaScript;Rust;SQL;TypeScript;Other(s):
# 371                                                 NaN
# 521                                 HTML/CSS;JavaScript
#
#                                           DatabaseWorkedWith  \
# Respondent
# 5           Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# 7                                                        NaN
# 329             Microsoft SQL Server;MySQL;PostgreSQL;SQLite
# 371                               MySQL;PostgreSQL;Other(s):
# 521                                                      NaN
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# 7                                                         NaN
# 329              Microsoft SQL Server;MySQL;PostgreSQL;SQLite
# 371                 Microsoft SQL Server;PostgreSQL;Other(s):
# 521                                                       NaN
#
#                            PlatformWorkedWith  \
# Respondent
# 5           Android;Linux;MacOS;Slack;Windows
# 7                               MacOS;Windows
# 329                               iOS;Windows
# 371                                       AWS
# 521                                       NaN
#
#                            PlatformDesireNextYear  \
# Respondent
# 5           Android;Docker;Kubernetes;Linux;Slack
# 7                                   MacOS;Windows
# 329                       Android;iOS;Linux;MacOS
# 371                                           AWS
# 521                                           NaN
#
#                                      WebFrameWorkedWith  \
# Respondent
# 5           Django;Express;Flask;jQuery;React.js;Spring
# 7                                              React.js
# 329         Angular/Angular.js;ASP.NET;Express;React.js
# 371                                                 NaN
# 521           Angular/Angular.js;jQuery;React.js;Vue.js
#
#                          WebFrameDesireNextYear  \
# Respondent
# 5                  Flask;jQuery;React.js;Spring
# 7                                      React.js
# 329         Angular/Angular.js;Express;React.js
# 371                                         NaN
# 521                      jQuery;React.js;Vue.js
#
#                              MiscTechWorkedWith  \
# Respondent
# 5                               Cordova;Node.js
# 7                                           NaN
# 329         .NET;.NET Core;Node.js;React Native
# 371                                      Pandas
# 521                                         NaN
#
#                               MiscTechDesireNextYear  \
# Respondent
# 5           Apache Spark;Hadoop;Node.js;React Native
# 7                                                NaN
# 329                             Node.js;React Native
# 371                                           Pandas
# 521                                  Flutter;Node.js
#
#                                   DevEnviron        OpSys  \
# Respondent
# 5                     IntelliJ;Notepad++;Vim  Linux-based
# 7                                   PHPStorm      Windows
# 329         Visual Studio;Visual Studio Code      Windows
# 371          Notepad++;PyCharm;Visual Studio      Windows
# 521                       Visual Studio Code      Windows
#
#                                         Containers  \
# Respondent
# 5           Outside of work, for personal projects
# 7                          I do not use containers
# 329                        I do not use containers
# 371                        I do not use containers
# 521                        I do not use containers
#
#                                          BlockchainOrg  \
# Respondent
# 5                                           Not at all
# 7                                                  NaN
# 329         Implementing cryptocurrency-based products
# 371                                                NaN
# 521                                         Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 5                                                         NaN        Yes
# 7           Useful for decentralized currency (i.e., Bitcoin)         No
# 329         Useful across many domains and could change ma...         No
# 371                                                       NaN        Yes
# 521                                                       NaN        Yes
#
#             ITperson OffOn SocialMedia              Extraversion ScreenName  \
# Respondent
# 5           Also Yes   Yes    Facebook  In real life (in person)   Username
# 7                Yes    No     YouTube                       NaN        NaN
# 329              Yes   Yes     Twitter                    Online      Login
# 371              Yes   Yes    LinkedIn                    Online        NaN
# 521              Yes   Yes     YouTube  In real life (in person)   Username
#
#                   SOVisit1st             SOVisitFreq  \
# Respondent
# 5           I don't remember  Multiple times per day
# 7                       2014   Daily or almost daily
# 329         I don't remember  Multiple times per day
# 371                     2013   Daily or almost daily
# 521                     2012    A few times per week
#
#                                                     SOVisitTo  \
# Respondent
# 5                          Find answers to specific questions
# 7                          Find answers to specific questions
# 329         Find answers to specific questions;Contribute ...
# 371                        Find answers to specific questions
# 521                        Find answers to specific questions
#
#                            SOFindAnswer                     SOTimeSaved  \
# Respondent
# 5           More than 10 times per week  Stack Overflow was much faster
# 7                    3-5 times per week                             NaN
# 329         More than 10 times per week  Stack Overflow was much faster
# 371                  3-5 times per week  Stack Overflow was much faster
# 521                  1-2 times per week  Stack Overflow was much faster
#
#             SOHowMuchTime                  SOAccount  \
# Respondent
# 5                     NaN                        Yes
# 7                     NaN                        Yes
# 329         11-30 minutes                        Yes
# 371         11-30 minutes  Not sure / can't remember
# 521          0-10 minutes                        Yes
#
#                                                    SOPartFreq  \
# Respondent
# 5                             A few times per month or weekly
# 7                         Less than once per month or monthly
# 329         I have never participated in Q&A on Stack Over...
# 371                                                       NaN
# 521         I have never participated in Q&A on Stack Over...
#
#                                                        SOJobs  \
# Respondent
# 5           No, I knew that Stack Overflow had a job board...
# 7                                                         Yes
# 329                                                       Yes
# 371                                                       Yes
# 521         No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 5           No, I've heard of them, but I am not part of a...
# 7                         No, and I don't know what those are
# 329         No, I've heard of them, but I am not part of a...
# 371                       No, and I don't know what those are
# 521                       No, and I don't know what those are
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 5           Yes, definitely  Just as welcome now as I felt last year
# 7                   Neutral    A lot more welcome now than last year
# 329           Yes, somewhat  Just as welcome now as I felt last year
# 371                 Neutral  Just as welcome now as I felt last year
# 521          No, not at all  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
# 7                                                         NaN  42.0    Man
# 329                                                       NaN  47.0    Man
# 371         Tech articles written by other developers;Indu...  30.0    Man
# 521                                                       NaN  35.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 5             No  Straight / Heterosexual
# 7             No  Straight / Heterosexual
# 329           No  Straight / Heterosexual
# 371           No  Straight / Heterosexual
# 521           No  Straight / Heterosexual
#
#                                            Ethnicity Dependents  \
# Respondent
# 5           White or of European descent;Multiracial         No
# 7                       White or of European descent        Yes
# 329                     White or of European descent        Yes
# 371                     White or of European descent         No
# 521                     White or of European descent        Yes
#
#                      SurveyLength                  SurveyEase
# Respondent
# 5           Appropriate in length                        Easy
# 7           Appropriate in length  Neither easy nor difficult
# 329                      Too long  Neither easy nor difficult
# 371                      Too long                        Easy
# 521                      Too long  Neither easy nor difficult

# %%
ukr_df.to_csv('data/modified.csv')

# %%
ukr_df.to_csv('data/modified.tsv', sep='\t')

# %%
ukr_df.to_excel('data/modified.xlsx')

# %%
test = pd.read_excel('data/modified.xlsx', index_col='Respondent')

# %%
test.head()
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 5           I am a developer by profession      Yes
# 7           I am a developer by profession       No
# 329         I am a developer by profession      Yes
# 371         I am a developer by profession       No
# 521         I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 5           Once a month or more often
# 7                                Never
# 329            Less than once per year
# 371                              Never
# 521                              Never
#
#                                                    OpenSource  \
# Respondent
# 5           OSS is, on average, of HIGHER quality than pro...
# 7           The quality of OSS and closed source software ...
# 329         The quality of OSS and closed source software ...
# 371         OSS is, on average, of LOWER quality than prop...
# 521         The quality of OSS and closed source software ...
#
#                                                    Employment  Country  \
# Respondent
# 5                                          Employed full-time  Ukraine
# 7           Independent contractor, freelancer, or self-em...  Ukraine
# 329                                        Employed full-time  Ukraine
# 371                                        Employed full-time  Ukraine
# 521                                        Employed full-time  Ukraine
#
#            Student                                            EdLevel  \
# Respondent
# 5               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7               No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 329            NaN  Some college/university study without earning ...
# 371             No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 521             No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
#
#                                                UndergradMajor  \
# Respondent
# 5           Computer science, computer engineering, or sof...
# 7           Another engineering discipline (ex. civil, ele...
# 329         Computer science, computer engineering, or sof...
# 371         Computer science, computer engineering, or sof...
# 521         Another engineering discipline (ex. civil, ele...
#
#                                                      EduOther  \
# Respondent
# 5           Taken an online course in programming or softw...
# 7           Taught yourself a new language, framework, or ...
# 329                                                       NaN
# 371                                                       NaN
# 521         Taken an online course in programming or softw...
#
#                                                       OrgSize  \
# Respondent
# 5                                    10,000 or more employees
# 7           Just me - I am a freelancer, sole proprietor, ...
# 329                                      100 to 499 employees
# 371                                      500 to 999 employees
# 521                                  10,000 or more employees
#
#                                                       DevType YearsCode  \
# Respondent
# 5           Academic researcher;Developer, desktop or ente...        16
# 7                               Designer;Developer, front-end         6
# 329         Academic researcher;Database administrator;Des...        20
# 371         Data or business analyst;Database administrato...        10
# 521                                      Developer, front-end         5
#
#            Age1stCode YearsCodePro                           CareerSat  \
# Respondent
# 5                  14            9                   Very dissatisfied
# 7                  17            4                  Slightly satisfied
# 329                15           10  Neither satisfied nor dissatisfied
# 371                21            7                      Very satisfied
# 521                 8            5                      Very satisfied
#
#                                         JobSat              MgrIdiot MgrMoney  \
# Respondent
# 5                        Slightly dissatisfied    Somewhat confident      Yes
# 7           Neither satisfied nor dissatisfied                   NaN      NaN
# 329         Neither satisfied nor dissatisfied  Not at all confident       No
# 371                             Very satisfied    Somewhat confident       No
# 521                         Slightly satisfied    Somewhat confident      Yes
#
#            MgrWant                                            JobSeek  \
# Respondent
# 5               No       I am not interested in new job opportunities
# 7              NaN  I’m not actively looking, but I am open to new...
# 329             No  I’m not actively looking, but I am open to new...
# 371             No       I am not interested in new job opportunities
# 521             No       I am not interested in new job opportunities
#
#                                                  LastHireDate  \
# Respondent
# 5                                        Less than a year ago
# 7           NA - I am an independent contractor or self em...
# 329                                     More than 4 years ago
# 371                                      Less than a year ago
# 521                                      Less than a year ago
#
#                                                       LastInt FizzBuzz  \
# Respondent
# 5           Write any code;Write code by hand (e.g., on a ...       No
# 7                                              Write any code       No
# 329         Write any code;Write code by hand (e.g., on a ...       No
# 371         Interview with people in senior / management r...       No
# 521         Complete a take-home project;Interview with pe...       No
#
#                                                    JobFactors  \
# Respondent
# 5           Industry that I'd be working in;Languages, fra...
# 7           Remote work options;Opportunities for professi...
# 329         Financial performance or funding status of the...
# 371         Financial performance or funding status of the...
# 521         Financial performance or funding status of the...
#
#                                 ResumeUpdate CurrencySymbol  \
# Respondent
# 5           I was preparing for a job search            UAH
# 7                                        NaN            USD
# 329         I was preparing for a job search            USD
# 371         I was preparing for a job search            UAH
# 521         I was preparing for a job search            USD
#
#                     CurrencyDesc  CompTotal CompFreq  ConvertedComp  \
# Respondent
# 5              Ukrainian hryvnia        NaN      NaN            NaN
# 7           United States dollar        NaN      NaN            NaN
# 329         United States dollar     4000.0  Monthly        48000.0
# 371            Ukrainian hryvnia        NaN      NaN            NaN
# 521         United States dollar     2300.0   Yearly         2300.0
#
#             WorkWeekHrs                                           WorkPlan  \
# Respondent
# 5                  55.0  There is a schedule and/or spec (made by me or...
# 7                  32.0  There is a schedule and/or spec (made by me or...
# 329                 NaN  There is a schedule and/or spec (made by me or...
# 371                40.0  There is a schedule and/or spec (made by me or...
# 521                40.0  There is a schedule and/or spec (made by me or...
#
#                                                 WorkChallenge  \
# Respondent
# 5           Being tasked with non-development work;Inadequ...
# 7           Being tasked with non-development work;Distrac...
# 329         Being tasked with non-development work;Distrac...
# 371                                                       NaN
# 521         Distracting work environment;Lack of support f...
#
#                                                    WorkRemote  \
# Respondent
# 5                                       A few days each month
# 7           All or almost all the time (I'm full-time remote)
# 329                                     A few days each month
# 371                                          It's complicated
# 521                          Less than once per month / Never
#
#                                                    WorkLoc  \
# Respondent
# 5                                                   Office
# 7           Other place, such as a coworking space or cafe
# 329                                                 Office
# 371                                                 Office
# 521                                                 Office
#
#                             ImpSyn                                  CodeRev  \
# Respondent
# 5           A little above average  Yes, because I see value in code review
# 7                          Average  Yes, because I see value in code review
# 329              Far above average  Yes, because I see value in code review
# 371         A little above average  Yes, because I see value in code review
# 521         A little above average  Yes, because I see value in code review
#
#             CodeRevHrs                      UnitTests PurchaseHow  \
# Respondent
# 5                  NaN  Yes, it's part of our process    Not sure
# 7                  6.0                            NaN         NaN
# 329                NaN  Yes, it's part of our process    Not sure
# 371                NaN  Yes, it's part of our process    Not sure
# 521                1.0      No, and I'm glad we don't    Not sure
#
#                              PurchaseWhat  \
# Respondent
# 5           I have little or no influence
# 7                                     NaN
# 329                 I have some influence
# 371                 I have some influence
# 521         I have little or no influence
#
#                                            LanguageWorkedWith  \
# Respondent
# 5                 C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7                                         HTML/CSS;JavaScript
# 329         C;C++;C#;F#;HTML/CSS;JavaScript;Rust;SQL;TypeS...
# 371                                 Bash/Shell/PowerShell;SQL
# 521                                       HTML/CSS;JavaScript
#
#                                  LanguageDesireNextYear  \
# Respondent
# 5              HTML/CSS;Java;JavaScript;SQL;WebAssembly
# 7                                   HTML/CSS;JavaScript
# 329         F#;JavaScript;Rust;SQL;TypeScript;Other(s):
# 371                                                 NaN
# 521                                 HTML/CSS;JavaScript
#
#                                           DatabaseWorkedWith  \
# Respondent
# 5           Couchbase;MongoDB;MySQL;Oracle;PostgreSQL;SQLite
# 7                                                        NaN
# 329             Microsoft SQL Server;MySQL;PostgreSQL;SQLite
# 371                               MySQL;PostgreSQL;Other(s):
# 521                                                      NaN
#
#                                        DatabaseDesireNextYear  \
# Respondent
# 5           Couchbase;Firebase;MongoDB;MySQL;Oracle;Postgr...
# 7                                                         NaN
# 329              Microsoft SQL Server;MySQL;PostgreSQL;SQLite
# 371                 Microsoft SQL Server;PostgreSQL;Other(s):
# 521                                                       NaN
#
#                            PlatformWorkedWith  \
# Respondent
# 5           Android;Linux;MacOS;Slack;Windows
# 7                               MacOS;Windows
# 329                               iOS;Windows
# 371                                       AWS
# 521                                       NaN
#
#                            PlatformDesireNextYear  \
# Respondent
# 5           Android;Docker;Kubernetes;Linux;Slack
# 7                                   MacOS;Windows
# 329                       Android;iOS;Linux;MacOS
# 371                                           AWS
# 521                                           NaN
#
#                                      WebFrameWorkedWith  \
# Respondent
# 5           Django;Express;Flask;jQuery;React.js;Spring
# 7                                              React.js
# 329         Angular/Angular.js;ASP.NET;Express;React.js
# 371                                                 NaN
# 521           Angular/Angular.js;jQuery;React.js;Vue.js
#
#                          WebFrameDesireNextYear  \
# Respondent
# 5                  Flask;jQuery;React.js;Spring
# 7                                      React.js
# 329         Angular/Angular.js;Express;React.js
# 371                                         NaN
# 521                      jQuery;React.js;Vue.js
#
#                              MiscTechWorkedWith  \
# Respondent
# 5                               Cordova;Node.js
# 7                                           NaN
# 329         .NET;.NET Core;Node.js;React Native
# 371                                      Pandas
# 521                                         NaN
#
#                               MiscTechDesireNextYear  \
# Respondent
# 5           Apache Spark;Hadoop;Node.js;React Native
# 7                                                NaN
# 329                             Node.js;React Native
# 371                                           Pandas
# 521                                  Flutter;Node.js
#
#                                   DevEnviron        OpSys  \
# Respondent
# 5                     IntelliJ;Notepad++;Vim  Linux-based
# 7                                   PHPStorm      Windows
# 329         Visual Studio;Visual Studio Code      Windows
# 371          Notepad++;PyCharm;Visual Studio      Windows
# 521                       Visual Studio Code      Windows
#
#                                         Containers  \
# Respondent
# 5           Outside of work, for personal projects
# 7                          I do not use containers
# 329                        I do not use containers
# 371                        I do not use containers
# 521                        I do not use containers
#
#                                          BlockchainOrg  \
# Respondent
# 5                                           Not at all
# 7                                                  NaN
# 329         Implementing cryptocurrency-based products
# 371                                                NaN
# 521                                         Not at all
#
#                                                  BlockchainIs BetterLife  \
# Respondent
# 5                                                         NaN        Yes
# 7           Useful for decentralized currency (i.e., Bitcoin)         No
# 329         Useful across many domains and could change ma...         No
# 371                                                       NaN        Yes
# 521                                                       NaN        Yes
#
#             ITperson OffOn SocialMedia              Extraversion ScreenName  \
# Respondent
# 5           Also Yes   Yes    Facebook  In real life (in person)   Username
# 7                Yes    No     YouTube                       NaN        NaN
# 329              Yes   Yes     Twitter                    Online      Login
# 371              Yes   Yes    LinkedIn                    Online        NaN
# 521              Yes   Yes     YouTube  In real life (in person)   Username
#
#                   SOVisit1st             SOVisitFreq  \
# Respondent
# 5           I don't remember  Multiple times per day
# 7                       2014   Daily or almost daily
# 329         I don't remember  Multiple times per day
# 371                     2013   Daily or almost daily
# 521                     2012    A few times per week
#
#                                                     SOVisitTo  \
# Respondent
# 5                          Find answers to specific questions
# 7                          Find answers to specific questions
# 329         Find answers to specific questions;Contribute ...
# 371                        Find answers to specific questions
# 521                        Find answers to specific questions
#
#                            SOFindAnswer                     SOTimeSaved  \
# Respondent
# 5           More than 10 times per week  Stack Overflow was much faster
# 7                    3-5 times per week                             NaN
# 329         More than 10 times per week  Stack Overflow was much faster
# 371                  3-5 times per week  Stack Overflow was much faster
# 521                  1-2 times per week  Stack Overflow was much faster
#
#             SOHowMuchTime                  SOAccount  \
# Respondent
# 5                     NaN                        Yes
# 7                     NaN                        Yes
# 329         11-30 minutes                        Yes
# 371         11-30 minutes  Not sure / can't remember
# 521          0-10 minutes                        Yes
#
#                                                    SOPartFreq  \
# Respondent
# 5                             A few times per month or weekly
# 7                         Less than once per month or monthly
# 329         I have never participated in Q&A on Stack Over...
# 371                                                       NaN
# 521         I have never participated in Q&A on Stack Over...
#
#                                                        SOJobs  \
# Respondent
# 5           No, I knew that Stack Overflow had a job board...
# 7                                                         Yes
# 329                                                       Yes
# 371                                                       Yes
# 521         No, I knew that Stack Overflow had a job board...
#
#                                                      EntTeams  \
# Respondent
# 5           No, I've heard of them, but I am not part of a...
# 7                         No, and I don't know what those are
# 329         No, I've heard of them, but I am not part of a...
# 371                       No, and I don't know what those are
# 521                       No, and I don't know what those are
#
#                      SOComm                            WelcomeChange  \
# Respondent
# 5           Yes, definitely  Just as welcome now as I felt last year
# 7                   Neutral    A lot more welcome now than last year
# 329           Yes, somewhat  Just as welcome now as I felt last year
# 371                 Neutral  Just as welcome now as I felt last year
# 521          No, not at all  Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
# 7                                                         NaN  42.0    Man
# 329                                                       NaN  47.0    Man
# 371         Tech articles written by other developers;Indu...  30.0    Man
# 521                                                       NaN  35.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 5             No  Straight / Heterosexual
# 7             No  Straight / Heterosexual
# 329           No  Straight / Heterosexual
# 371           No  Straight / Heterosexual
# 521           No  Straight / Heterosexual
#
#                                            Ethnicity Dependents  \
# Respondent
# 5           White or of European descent;Multiracial         No
# 7                       White or of European descent        Yes
# 329                     White or of European descent        Yes
# 371                     White or of European descent         No
# 521                     White or of European descent        Yes
#
#                      SurveyLength                  SurveyEase
# Respondent
# 5           Appropriate in length                        Easy
# 7           Appropriate in length  Neither easy nor difficult
# 329                      Too long  Neither easy nor difficult
# 371                      Too long                        Easy
# 521                      Too long  Neither easy nor difficult
